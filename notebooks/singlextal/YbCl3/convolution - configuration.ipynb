# %% [markdown]
# # README
# This should be run after "resolution all in one"

# %%
import sys
# sys.path.insert(0, '/SNS/users/lj7/dv/mcvine/dgsres/')
import dgsres
dgsres

# %% [markdown]
# ## Configuration file
# Modify the path if necessary

# %%
# %%file convolution_config.py
import os, numpy as np, imp
narr = np.array
from dgsres import axis
from dgsres.singlextal import convolve2d as cvv2
here = os.path.abspath(os.path.dirname(__file__) or '.')
rwc = imp.load_source('rwc', os.path.join(here, './mcvinesim/resolution_workflow_config.py'))

resolution_datadir = os.path.join(here, 'mcvinesim')

class Slice_H00(rwc.Slice_H00): 
    
    class expdata:
        class grid:
            qaxis = axis(min=0, max=4.+1e-5, step=0.5/10)
            Eaxis = axis(min=0., max=2.4+1e-5, step=0.025)
        perp_hkl_directions = narr([[0.,1.,0.], [0.,0.,1.]])
        dh = 0.05
        perp_hkl_range = narr([[-dh, dh], [-1.3, 1.3]])
        Nsample_perp_hkl = 20  # this is for sampling the perp directions.
        
    class convolution:
        expansion_ratio = 0.1
        N_subpixels = 5,5

class Slice_H10(rwc.Slice_H10):
    
    class expdata:
        class grid:
            qaxis = axis(min=0, max=4.+1e-5, step=0.5/10)
            Eaxis = axis(min=0., max=2.4+1e-5, step=0.025)
        perp_hkl_directions = narr([[0.,1.,0.], [0.,0.,1.]])
        dh = 0.05
        perp_hkl_range = narr([[-dh, dh], [-1.3, 1.3]])
        Nsample_perp_hkl = 20  # this is for sampling the perp directions.
    
    class convolution:
        expansion_ratio = 0.1
        N_subpixels = 5,5        

class Slice_H20(rwc.Slice_H20):
    
    class expdata:
        class grid:
            qaxis = axis(min=0, max=4.+1e-5, step=0.5/10)
            Eaxis = axis(min=0., max=2.4+1e-5, step=0.025)
        perp_hkl_directions = narr([[0.,1.,0.], [0.,0.,1.]])
        dh = 0.05
        perp_hkl_range = narr([[-dh, dh], [-1.3, 1.3]])
        Nsample_perp_hkl = 20  # this is for sampling the perp directions.
    
    class convolution:
        expansion_ratio = 0.1
        N_subpixels = 5,5
        
class Slice_0K0(rwc.Slice_0K0):
    
    class expdata:
        class grid:
            qaxis = axis(min=0, max=4.+1e-5, step=0.5/10)
            Eaxis = axis(min=0., max=2.4+1e-5, step=0.025)
        perp_hkl_directions = narr([[0.,1.,0.], [0.,0.,1.]])
        dh = 0.05
        perp_hkl_range = narr([[-dh, dh], [-1.3, 1.3]])
        Nsample_perp_hkl = 20  # this is for sampling the perp directions.
    
    class convolution:
        expansion_ratio = 0.1
        N_subpixels = 5,5

class Slice_1K0(rwc.Slice_1K0):
    
    class expdata:
        class grid:
            qaxis = axis(min=0, max=4.+1e-5, step=0.5/10)
            Eaxis = axis(min=0., max=2.4+1e-5, step=0.025)
        perp_hkl_directions = narr([[0.,1.,0.], [0.,0.,1.]])
        dh = 0.05
        perp_hkl_range = narr([[-dh, dh], [-1.3, 1.3]])
        Nsample_perp_hkl = 20  # this is for sampling the perp directions.
    
    class convolution:
        expansion_ratio = 0.1
        N_subpixels = 5,5

class Slice_HH0(rwc.Slice_HH0):
    
    class expdata:
        class grid:
            qaxis = axis(min=0, max=4.+1e-5, step=0.5/10)
            Eaxis = axis(min=0., max=2.4+1e-5, step=0.025)
        perp_hkl_directions = narr([[1.,-1.,0.], [0.,0.,1.]])
        dh = 0.05
        perp_hkl_range = narr([[-dh, dh], [-1.3, 1.3]])
        Nsample_perp_hkl = 20  # this is for sampling the perp directions.
    
    class convolution:
        expansion_ratio = 0.1
        N_subpixels = 5,5

class Slice_0p5K0(rwc.Slice_0p5K0):
    
    class expdata:
        class grid:
            qaxis = axis(min=0, max=4.+1e-5, step=0.5/10)
            Eaxis = axis(min=0., max=2.4+1e-5, step=0.025)
        perp_hkl_directions = narr([[0.,1.,0.], [0.,0.,1.]])
        dh = 0.05
        perp_hkl_range = narr([[-dh, dh], [-1.3, 1.3]])
        Nsample_perp_hkl = 20  # this is for sampling the perp directions.
    
    class convolution:
        expansion_ratio = 0.1
        N_subpixels = 5,5
        
slices = [Slice_H00, Slice_H10, Slice_H20, Slice_0K0, Slice_1K0, Slice_HH0, Slice_0p5K0]
# slices = [Slice_00L]
for sl in slices:
    sl.resolution_datadir = resolution_datadir

# %%
import imp
config = imp.load_source('config', './convolution_config.py')
