# %%
workdir = '/SNS/users/lj7/dv/mcvine/dgsres/notebooks/powder2D-shear/'
# %cd {workdir}
# Out:
# /SNS/users/lj7/dv/mcvine/dgsres/notebooks/powder2D-shear

# %%
import numpy as np, os

# %%
mat = np.loadtxt('./inputimg.dat')

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib notebook

# %%
mat1 = mat[:, 750:1000]

# %%
plt.figure()
plt.imshow(mat1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
nrows, ncols = mat1.shape

# %% [markdown]
# x2-x2_origin = x1 - x1_origin + (y1-y1_origin)*C
#
# x1_origin = 153
#
# y1_origin = 100

# %%
x1_origin = 153
y1_origin = 100

# %%
x = np.arange(ncols)
y = np.arange(nrows)

# %%
xg,yg = np.meshgrid(x,y)

# %%
C = -.4
xg2 = xg + (yg - y1_origin)*C

# %%
xs = xg.view(); xs.shape = -1,
ys = yg.view(); ys.shape = -1,
xs2 = xg2.view(); xs2.shape = -1,
points = np.array([xs, ys]).T.copy()
values = mat1.copy()
xi = np.array([xs2, ys]).T.copy()

# %%
values.shape = -1,

# %%
import scipy.interpolate as sint

# %%
zs = sint.griddata(points, values, xi)

# %%
zs.shape = mat1.shape

# %%
plt.figure()
plt.imshow(zs)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
